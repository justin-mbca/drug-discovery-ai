# %%
# Example: Download a PDB structure using Biopython
from Bio.PDB import PDBList
pdbl = PDBList()
pdb_id = '1BNA'
pdbl.retrieve_pdb_file(pdb_id, pdir='.', file_format='pdb')

# %%
# Example: Visualize a protein structure with nglview (if installed)
# !pip install nglview
import nglview as nv
view = nv.show_file('pdb1bna.ent')
view

# %% [markdown]
# ## Applications
# - Protein structure analysis guides drug design and docking.
# - AlphaFold and other tools enable accurate structure prediction.
# - Visualization helps interpret protein-ligand interactions.
